# %% [markdown]
# <a href="https://colab.research.google.com/github/Lavsdyc/AluraStore/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# ### **Ingreso total por cada tienda**
#
# En este primer análisis, debes calcular el ingreso total de cada tienda. Sumando los valores de la columna Precio de cada conjunto de datos de la tienda para estimar los ingresos.

# %%
ingresos_tienda1 = tienda['Precio'].sum()
ingresos_tienda2 = tienda2['Precio'].sum()
ingresos_tienda3 = tienda3['Precio'].sum()
ingresos_tienda4 = tienda4['Precio'].sum()
ingresos_totales = ingresos_tienda1 + ingresos_tienda2 + ingresos_tienda3 + ingresos_tienda4

# %%
print(f"Ingresos totales de la tienda 1: ${ingresos_tienda1:,.2f}")
print(f"Ingresos totales de la tienda 2: ${ingresos_tienda2:,.2f}")
print(f"Ingresos totales de la tienda 3: ${ingresos_tienda3:,.2f}")
print(f"Ingresos totales de la tienda 4: ${ingresos_tienda4:,.2f}")
print(f"Ingresos totales de todas las tiendas: ${ingresos_totales:,.2f}")
# Out:
# Ingresos totales de la tienda 1: $1,150,880,400.00
# Ingresos totales de la tienda 2: $1,116,343,500.00
# Ingresos totales de la tienda 3: $1,098,019,600.00
# Ingresos totales de la tienda 4: $1,038,375,700.00
# Ingresos totales de todas las tiendas: $4,403,619,200.00

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# En este debes calcular la cantidad de productos vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.

# %%
categorias_tienda1 = tienda['Categoría del Producto'].value_counts()
categorias_tienda2 = tienda2['Categoría del Producto'].value_counts()
categorias_tienda3 = tienda3['Categoría del Producto'].value_counts()
categorias_tienda4 = tienda4['Categoría del Producto'].value_counts()
print("Ventas por categoría de la tienda 1:")
print(categorias_tienda1)
print("\nVentas por categoría de la tienda 2:")
print(categorias_tienda2)
print("\nVentas por categoría de la tienda 3:")
print(categorias_tienda3)
print("\nVentas por categoría de la tienda 4:")
print(categorias_tienda4)
# Out:
# Ventas por categoría de la tienda 1:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64
#
# Ventas por categoría de la tienda 2:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64
#
# Ventas por categoría de la tienda 3:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# En este paso, debes calcular las calificaciones promedio de los clientes para cada tienda. El objetivo es conocer la satisfacción del cliente con los productos vendidos.

# %%
calificacion_tienda1 = tienda['Calificación'].mean()
calificacion_tienda2 = tienda2['Calificación'].mean()
calificacion_tienda3 = tienda3['Calificación'].mean()
calificacion_tienda4 = tienda4['Calificación'].mean()

print(f"Calificación promedio de la tienda 1: {calificacion_tienda1:.2f}")
print(f"Calificación promedio de la tienda 2: {calificacion_tienda2:.2f}")
print(f"Calificación promedio de la tienda 3: {calificacion_tienda3:.2f}")
print(f"Calificación promedio de la tienda 4: {calificacion_tienda4:.2f}")
# Out:
# Calificación promedio de la tienda 1: 3.98
# Calificación promedio de la tienda 2: 4.04
# Calificación promedio de la tienda 3: 4.05
# Calificación promedio de la tienda 4: 4.00

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# En este paso, debes identificar qué productos fueron los más vendidos y los menos vendidos en cada tienda. Visualiza los resultados para que quede claro qué productos destacaron en ventas en cada tienda.

# %%
import matplotlib.pyplot as plt

def producto_masmenosvendido(tienda, numero):
    conteo_productos = tienda['Producto'].value_counts()

    producto_mas = conteo_productos.idxmax()
    ventas_mas = conteo_productos.max()

    producto_menos = conteo_productos.idxmin()
    ventas_menos = conteo_productos.min()

    productos = [producto_menos, producto_mas]
    ventas = [ventas_menos, ventas_mas]
    colores = ['yellow', 'blue']

    plt.figure(figsize=(6, 4))
    barras = plt.bar(productos, ventas, color=colores)
    plt.title(f"Producto Menos Vendido vs. Más Vendido en Tienda {numero}")
    plt.ylabel("Cantidad de Ventas")

    for barra, venta in zip(barras, ventas):
        plt.text(
            barra.get_x() + barra.get_width()/2,
            venta + 1,
            f"{venta} ventas",
            ha='center'
        )

    plt.tight_layout()
    plt.show()


producto_masmenosvendido(tienda, 1)
producto_masmenosvendido(tienda2, 2)
producto_masmenosvendido(tienda3, 3)
producto_masmenosvendido(tienda4, 4)

# %% [markdown]
# # 5. Envío promedio por tienda

# %% [markdown]
# En este paso, debes calcular el costo de envío promedio para cada tienda. El objetivo es comprender cuánto se gasta, en promedio, en el envío de cada tienda.  Sabiendo que el cliente paga el envío.

# %%
from numpy import cos
costo_envio_tienda1 = tienda['Costo de envío'].mean()
costo_envio_tienda2 = tienda2['Costo de envío'].mean()
costo_envio_tienda3 = tienda3['Costo de envío'].mean()
costo_envio_tienda4 = tienda4['Costo de envío'].mean()

print(f"Costo de envío promedio de la tienda 1: ${costo_envio_tienda1:.2f}")
print(f"Costo de envío promedio de la tienda 2: ${costo_envio_tienda2:.2f}")
print(f"Costo de envío promedio de la tienda 3: ${costo_envio_tienda3:.2f}")
print(f"Costo de envío promedio de la tienda 4: ${costo_envio_tienda4:.2f}")
# Out:
# Costo de envío promedio de la tienda 1: $26018.61
# Costo de envío promedio de la tienda 2: $25216.24
# Costo de envío promedio de la tienda 3: $24805.68
# Costo de envío promedio de la tienda 4: $23459.46

# %% [markdown]
# # **Visualización**

# %% [markdown]
# ## **Generando gráfico**
#
# Después de realizar los análisis, es hora de transformar sus resultados en visualizaciones que le ayuden a comprender mejor los patrones y los insights encontrados.
#
# De acuerdo con funciones que haya creado, le recomendamos que genere al menos tres gráficos. Estos gráficos deben ser de diferentes tipos (como barras, líneas, dispersión, entre otros) para presentar una visión completa de los datos.
#
# Recuerde que los gráficos deben complementar el análisis realizado, resaltando los puntos más relevantes, como los ingresos de la tienda, la distribución de categorías de productos, las opiniones de los clientes, los productos más vendidos y/o los costes de envío.
#
# No es necesario mostrar una visualización en cada paso, pero al final del análisis debes generar los gráficos que consideres más útiles para interpretar los datos.

# %% [markdown]
# ### **Ingresos por tienda**

# %%
import matplotlib.pyplot as plt

tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
ingresos = [
    tienda['Precio'].sum(),
    tienda2['Precio'].sum(),
    tienda3['Precio'].sum(),
    tienda4['Precio'].sum()
]

plt.figure(figsize=(7,4))
plt.bar(tiendas, ingresos, color='skyblue')
plt.title('Ingresos totales por tienda')
plt.ylabel('Ingresos')
plt.xlabel('Tienda')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Distribución de ventas por Categoría**

# %%
plt.figure(figsize=(8,8))
plt.pie(categorias_tienda1.values, labels=categorias_tienda1.index, autopct='%1.1f%%', startangle=140)
plt.title(' Ventas distribuidas por Categoría: Tienda 1')
plt.axis('equal')
plt.show()

plt.figure(figsize=(8,8))
plt.pie(categorias_tienda2.values, labels=categorias_tienda2.index, autopct='%1.1f%%', startangle=140)
plt.title(' Ventas distribuidas por Categoría: Tienda 2')
plt.axis('equal')
plt.show()


plt.figure(figsize=(8,8))
plt.pie(categorias_tienda3.values, labels=categorias_tienda3.index, autopct='%1.1f%%', startangle=140)
plt.title(' Ventas distribuidas por Categoría: Tienda 3')
plt.axis('equal')
plt.show()


plt.figure(figsize=(8,8))
plt.pie(categorias_tienda4.values, labels=categorias_tienda4.index, autopct='%1.1f%%', startangle=140)
plt.title(' Ventas distribuidas por Categoría: Tienda 4')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### **Envío promedio por tienda**

# %%
costo_envio_tienda1 = tienda['Costo de envío'].mean()
costo_envio_tienda2 = tienda2['Costo de envío'].mean()
costo_envio_tienda3 = tienda3['Costo de envío'].mean()
costo_envio_tienda4 = tienda4['Costo de envío'].mean()

nombres_tienda = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
promedios_envio = [
    costo_envio_tienda1,
    costo_envio_tienda2,
    costo_envio_tienda3,
    costo_envio_tienda4
]

import matplotlib.pyplot as plt

plt.figure(figsize=(7,4))
plt.plot(nombres_tienda, promedios_envio, marker='o', linestyle='--', color='orange')

for x, y in zip(nombres_tienda, promedios_envio):
    plt.text(x, y, f"${y:.2f}", ha='center', va='bottom')

plt.title('Costo de Envío Promedio por Tienda')
plt.xlabel('Tienda')
plt.ylabel('Costo de envío promedio')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Informe Final**

# %% [markdown]
# ## **Introducción**
#
# El propósito de este análisis fue evaluar el desempeño de cuatro tiendas de la cadena Alura Store Latam con el fin de determinar cuál representa la mejor opción para que el Sr. Juan realice la venta de su negocio. Para ello, se analizaron distintos factores clave relacionados con las ventas, el comportamiento de los clientes y los costos asociados, apoyándose en técnicas de análisis de datos y visualizaciones desarrolladas con Python y la biblioteca Matplotlib.
#
# Los criterios considerados incluyen los ingresos totales de cada tienda, las categorías de productos más y menos vendidas, las calificaciones promedio de los clientes, los productos más y menos vendidos, así como el costo de envío promedio por tienda.

# %% [markdown]
# ## **Desarrollo del análisis**
# En primer lugar, se analizaron los ingresos totales por tienda, lo que permitió identificar cuáles generan mayores ganancias. A partir de la gráfica de barras, se observó que existen diferencias claras entre las tiendas, destacando aquellas con un volumen de ventas más alto, lo cual representa una fortaleza importante desde el punto de vista financiero.
#
# Posteriormente, se estudió la distribución de las categorías de productos, identificando cuáles concentran la mayor parte de las ventas. Este análisis permitió comprender el enfoque comercial de cada tienda, así como detectar posibles dependencias excesivas de ciertas categorías o una falta de diversidad en la oferta de productos.
#
# En cuanto a la experiencia del cliente, se analizaron las calificaciones promedio otorgadas por los compradores. Este indicador resulta clave, ya que una buena valoración suele estar asociada con mayor fidelización y reputación de la tienda. Las diferencias entre tiendas reflejan fortalezas y debilidades en aspectos como calidad del producto, servicio y logística.
#
# Asimismo, se identificaron los productos más y menos vendidos de cada tienda. Este análisis permitió detectar qué artículos generan mayor demanda y cuáles podrían representar oportunidades de mejora o ajuste en la estrategia de ventas e inventario.
#
# Finalmente, se evaluó el costo de envío promedio por tienda, un factor relevante tanto para los clientes como para la competitividad del negocio. A través de la gráfica de líneas, fue posible comparar los costos logísticos y observar qué tiendas presentan costos más elevados, lo cual podría afectar la decisión de compra de los clientes.

# %% [markdown]
# ## **Conclusión y recomendación**
# Con base en el análisis integral de los datos y las visualizaciones generadas, se concluye que la tienda que el Sr. Juan debería vender es aquella que presenta un mejor equilibrio entre ingresos elevados, buena aceptación por parte de los clientes y costos de envío competitivos.
#
# Si bien algunas tiendas destacan por generar mayores ingresos, no todas mantienen calificaciones altas o costos de envío favorables. Por el contrario, la tienda recomendada logra combinar buen desempeño financiero, productos bien valorados, una oferta sólida de categorías y costos de envío razonables, lo que la convierte en la opción más atractiva y sostenible a largo plazo.
#
# En conclusión, la decisión se fundamenta en un análisis objetivo respaldado por datos y gráficos, permitiendo identificar de manera clara las fortalezas y debilidades de cada tienda y seleccionar la opción que ofrece el mayor potencial de éxito para el Sr. Juan.
